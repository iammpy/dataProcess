# %% [markdown]
# ### 初始化全局变量，导入包

# %%
import os
import sys
import json
from model import call_huoshan,call_openai
import pandas as pd
if "__file__" in globals():
    os.chdir(os.path.dirname(os.path.abspath(__file__)))

raw_data_path= os.path.join("raw_data")
scienceQA_path = os.path.join(raw_data_path, "ScienceQA")
sciKnowEval_path = os.path.join(raw_data_path, "SciKnowEval")

# %% [markdown]
# ### 查看并读取sciQA数据

# %%
ScienceQA_processed = os.path.join(raw_data_path, "ScienceQA_processed.json")
# ScienceQA_processed_with_image = os.path.join(raw_data_path, "ScienceQA_processed_with_image.json")
with open(ScienceQA_processed, "r") as f:
    sciQA_data = json.load(f)

# %%
image_output_dir = os.path.join(raw_data_path, "ScienceQA", "images")
os.makedirs(image_output_dir, exist_ok=True) # 如果文件夹不存在则创建

def save_image(row, id):
    if row["image"] is not None and isinstance(row["image"], dict) and "bytes" in row["image"]:
        image_bytes = row['image']['bytes']
        if image_bytes: # 确保字节数据不为空
            # 构建图片文件名，可以使用索引 i 或者其他唯一标识符
            # 假设图片是 png 格式，如果不是，需要根据实际情况调整扩展名
            image_filename = f"image_{id}.png"
            image_filepath = os.path.join(image_output_dir, image_filename)
            
            try:
                with open(image_filepath, "wb") as img_file: # "wb" 表示以二进制写入模式打开
                    img_file.write(image_bytes)
                # print(f"Saved image to {image_filepath}")
            except Exception as e:
                print(f"Error saving image {image_filepath}: {e}")

# %% [markdown]
# #### 根据一个问题，以及不同的文件类型，构建传给模型的最终prompt

# %%
def sciQA_build_prompt(row):
    question = row["question"]
    choices = row["choices"]
    hint= row["hint"]
    formatted_options = []
    for i, option_text in enumerate(choices):
        formatted_options.append(f'({i}): {option_text}') # 注意这里选项文本也被引号包围了
    choices_with_indices = "\n".join(formatted_options)
    prompt=f"""
Review the question and the options provided below. Each option is clearly labeled with its numerical index.
Select the option that best answers the question.
Respond with ONLY the numerical index label of your chosen option.
Your entire response must be a single integer. Do not include any other text or explanations.
Input (Optional, for reference only, may be empty or not needed):
{hint} 
Question:
{question}
Options:
{choices_with_indices}
Answer Index:
    """
    # prompt=f"""
    # 关于下面这些问题，我注意到有些问题的选项可能不完整或不准确。这个数据集是有三个字段，question、choices和hint。
    # 正常来说hint是用来提示问题的，但是对于某些question，hint可能就是上下文，缺少hint这个问题无法回答。
    # 我在下面给你每个问题的question、choices和hint，请你判断hint是否是回答这个问题所必须的。(注意，这里的必须指的是缺少hint这个无法通过任何推理选出某个选项)
    # 如果是，则返回"yes"，否则返回"no"，如果提供给你的hint是空的，则返回"null"
    # Question:
    # {question}
    # Choices:
    # {choices_with_indices}
    # Hint:
    # {hint}
    # 注意，回答只能是yes，或者no，或者null，不要包含其他任何字符。
    # Is the hint necessary to answer the question? (yes/no/null):
    # """
    return prompt

# %%
import hashlib

def generate_md5(input_string):
    # 创建一个 md5 hash 对象
    md5_hash = hashlib.md5()
    
    # 将输入的字符串转换为字节串（因为 hashlib 需要字节类型的数据）
    input_bytes = input_string.encode('utf-8')
    
    # 更新哈希对象
    md5_hash.update(input_bytes)
    
    # 获取哈希值的十六进制表示
    md5_digest = md5_hash.hexdigest()
    
    return md5_digest

# %% [markdown]
# #### 都是选择题，直接使用规则比对

# %%
def sciQA_rule_verifier(question, groundtruth, model_content):
    if groundtruth == model_content:
        return True
    else:
        return False

# %% [markdown]
# #### 处理sciQA数据：生成generation，调用verifier，整合成符合要求的最终dict格式

# %%
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock
import numpy as np
Lock = Lock()


def sciKnowEval_process_row(row):

    solution = row["metadata"]["solution"]
    final_answer=row["ground_truth"]["final_answer"]


    generations=row["generations"]
    if solution != "":
        row["ground_truth"]["solution"] = solution
    # for i in range(0): # 调用模型的次数，暂定为1
    #     generation={}
    #     generation["model"] = "DeepSeek-R1"
    #     reasoning_content, answer_content = call_huoshan(prompt,"r1")
    #     answer_content=answer_content.strip()
    #     generation["reasoning_content"] = reasoning_content
    #     generation["answer_content"] = answer_content
    #     # Verify the model content
    #     evaluation={}
    #     correctness = sciQA_rule_verifier(prompt, final_answer, answer_content) 
        
    #     evaluation["correctness"] = correctness
    #     evaluation["By"] = "mengpengyu"
    #     evaluation["Method"] = "Rule"
    #     evaluation["extra_tags"] = []
    #     generation["evaluation"] = evaluation
    #     generations.append(generation)

    # if len(generations) == 0:
    #     row["solve_rate"] = None
    # else:
    #     row["solve_rate"] = sum(1 for gen in generations if gen["evaluation"]["correctness"]) / len(generations)

# %%
import traceback
import pdb

with ThreadPoolExecutor(max_workers=200) as executor:
    counter = 0
    futures = {executor.submit(sciKnowEval_process_row, row): index for index, row in enumerate(sciQA_data)}
    for future in as_completed(futures):
        index = futures[future]
        try:
            future.result()  # 获取结果，确保异常被捕获
            counter += 1
            if counter % 10 == 0:
                print(f"Processed {counter} rows.")
        except Exception as e:
            print(f"Error processing row {index}: {e}")
            traceback.print_exc() 
# 将结果写入JSON文件
output_file = os.path.join(raw_data_path, "ScienceQA_processed.json")
output_file_with_image = os.path.join(raw_data_path, "ScienceQA_processed_with_image.json")
try:
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(sciQA_data, f, ensure_ascii=False, indent=4)   
        print(f"Results written to {output_file}")
    with open(output_file_with_image, "w", encoding="utf-8") as f:
        json.dump(sciQA_data, f, ensure_ascii=False, indent=4)   
        print(f"Results with images written to {output_file_with_image}")
except Exception as e:
    print(f"Error writing to file {output_file}: {e}")
    pdb.set_trace()
# Out:
# Processed 10 rows.
# Processed 20 rows.
# Processed 30 rows.
# Processed 40 rows.
# Processed 50 rows.
# Processed 60 rows.
# Processed 70 rows.
# Processed 80 rows.
# Processed 90 rows.
# Processed 100 rows.
# Processed 110 rows.
# Processed 120 rows.
# Processed 130 rows.
# Processed 140 rows.
# Processed 150 rows.
# Processed 160 rows.
# Processed 170 rows.
# Processed 180 rows.
# Processed 190 rows.
# Processed 200 rows.
# Processed 210 rows.
# Processed 220 rows.
# Processed 230 rows.
# Processed 240 rows.
# Processed 250 rows.
# Processed 260 rows.
# Processed 270 rows.
# Processed 280 rows.
# Processed 290 rows.
# Processed 300 rows.
# Processed 310 rows.
# Processed 320 rows.
# Processed 330 rows.
# Processed 340 rows.
# Processed 350 rows.
# Processed 360 rows.
# Processed 370 rows.
# Processed 380 rows.
# Processed 390 rows.
# Processed 400 rows.
# Processed 410 rows.
# Processed 420 rows.
# Processed 430 rows.
# Processed 440 rows.
# Processed 450 rows.
# Processed 460 rows.
# Processed 470 rows.
# Processed 480 rows.
# Processed 490 rows.
# Processed 500 rows.
# Processed 510 rows.
# Processed 520 rows.
# Processed 530 rows.
# Processed 540 rows.
# Processed 550 rows.
# Processed 560 rows.
# Processed 570 rows.
# Processed 580 rows.
# Processed 590 rows.
# Processed 600 rows.
# Processed 610 rows.
# Processed 620 rows.
# Processed 630 rows.
# Processed 640 rows.
# Processed 650 rows.
# Processed 660 rows.
# Processed 670 rows.
# Processed 680 rows.
# Processed 690 rows.
# Processed 700 rows.
# Processed 710 rows.
# Processed 720 rows.
# Processed 730 rows.
# Processed 740 rows.
# Processed 750 rows.
# Processed 760 rows.
# Processed 770 rows.
# Processed 780 rows.
# Processed 790 rows.
# Processed 800 rows.
# Processed 810 rows.
# Processed 820 rows.
# Processed 830 rows.
# Processed 840 rows.
# Processed 850 rows.
# Processed 860 rows.
# Processed 870 rows.
# Processed 880 rows.
# Processed 890 rows.
# Processed 900 rows.
# Processed 910 rows.
# Processed 920 rows.
# Processed 930 rows.
# Processed 940 rows.
# Processed 950 rows.
# Processed 960 rows.
# Processed 970 rows.
# Processed 980 rows.
# Processed 990 rows.
# Processed 1000 rows.
# Processed 1010 rows.
# Processed 1020 rows.
# Processed 1030 rows.
# Processed 1040 rows.
# Processed 1050 rows.
# Processed 1060 rows.
# Processed 1070 rows.
# Processed 1080 rows.
# Processed 1090 rows.
# Processed 1100 rows.
# Processed 1110 rows.
# Processed 1120 rows.
# Processed 1130 rows.
# Processed 1140 rows.
# Processed 1150 rows.
# Processed 1160 rows.
# Processed 1170 rows.
# Processed 1180 rows.
# Processed 1190 rows.
# Processed 1200 rows.
# Processed 1210 rows.
# Processed 1220 rows.
# Processed 1230 rows.
# Processed 1240 rows.
# Processed 1250 rows.
# Processed 1260 rows.
# Processed 1270 rows.
# Processed 1280 rows.
# Processed 1290 rows.
# Processed 1300 rows.
# Processed 1310 rows.
# Processed 1320 rows.
# Processed 1330 rows.
# Processed 1340 rows.
# Processed 1350 rows.
# Processed 1360 rows.
# Processed 1370 rows.
# Processed 1380 rows.
# Processed 1390 rows.
# Processed 1400 rows.
# Processed 1410 rows.
# Processed 1420 rows.
# Processed 1430 rows.
# Processed 1440 rows.
# Processed 1450 rows.
# Processed 1460 rows.
# Processed 1470 rows.
# Processed 1480 rows.
# Processed 1490 rows.
# Processed 1500 rows.
# Processed 1510 rows.
# Processed 1520 rows.
# Processed 1530 rows.
# Processed 1540 rows.
# Processed 1550 rows.
# Processed 1560 rows.
# Processed 1570 rows.
# Processed 1580 rows.
# Processed 1590 rows.
# Processed 1600 rows.
# Processed 1610 rows.
# Processed 1620 rows.
# Processed 1630 rows.
# Processed 1640 rows.
# Processed 1650 rows.
# Processed 1660 rows.
# Processed 1670 rows.
# Processed 1680 rows.
# Processed 1690 rows.
# Processed 1700 rows.
# Processed 1710 rows.
# Processed 1720 rows.
# Processed 1730 rows.
# Processed 1740 rows.
# Processed 1750 rows.
# Processed 1760 rows.
# Processed 1770 rows.
# Processed 1780 rows.
# Processed 1790 rows.
# Processed 1800 rows.
# Processed 1810 rows.
# Processed 1820 rows.
# Processed 1830 rows.
# Processed 1840 rows.
# Processed 1850 rows.
# Processed 1860 rows.
# Processed 1870 rows.
# Processed 1880 rows.
# Processed 1890 rows.
# Processed 1900 rows.
# Processed 1910 rows.
# Processed 1920 rows.
# Processed 1930 rows.
# Processed 1940 rows.
# Processed 1950 rows.
# Processed 1960 rows.
# Processed 1970 rows.
# Processed 1980 rows.
# Processed 1990 rows.
# Processed 2000 rows.
# Processed 2010 rows.
# Processed 2020 rows.
# Processed 2030 rows.
# Processed 2040 rows.
# Processed 2050 rows.
# Processed 2060 rows.
# Processed 2070 rows.
# Processed 2080 rows.
# Processed 2090 rows.
# Processed 2100 rows.
# Processed 2110 rows.
# Processed 2120 rows.
# Processed 2130 rows.
# Processed 2140 rows.
# Processed 2150 rows.
# Processed 2160 rows.
# Processed 2170 rows.
# Processed 2180 rows.
# Processed 2190 rows.
# Processed 2200 rows.
# Processed 2210 rows.
# Processed 2220 rows.
# Processed 2230 rows.
# Processed 2240 rows.
# Processed 2250 rows.
# Processed 2260 rows.
# Processed 2270 rows.
# Processed 2280 rows.
# Processed 2290 rows.
# Processed 2300 rows.
# Processed 2310 rows.
# Processed 2320 rows.
# Processed 2330 rows.
# Processed 2340 rows.
# Processed 2350 rows.
# Processed 2360 rows.
# Processed 2370 rows.
# Processed 2380 rows.
# Processed 2390 rows.
# Processed 2400 rows.
# Processed 2410 rows.
# Processed 2420 rows.
# Processed 2430 rows.
# Processed 2440 rows.
# Processed 2450 rows.
# Processed 2460 rows.
# Processed 2470 rows.
# Processed 2480 rows.
# Processed 2490 rows.
# Processed 2500 rows.
# Processed 2510 rows.
# Processed 2520 rows.
# Processed 2530 rows.
# Processed 2540 rows.
# Processed 2550 rows.
# Processed 2560 rows.
# Processed 2570 rows.
# Processed 2580 rows.
# Processed 2590 rows.
# Processed 2600 rows.
# Processed 2610 rows.
# Processed 2620 rows.
# Processed 2630 rows.
# Processed 2640 rows.
# Processed 2650 rows.
# Processed 2660 rows.
# Processed 2670 rows.
# Processed 2680 rows.
# Processed 2690 rows.
# Processed 2700 rows.
# Processed 2710 rows.
# Processed 2720 rows.
# Processed 2730 rows.
# Processed 2740 rows.
# Processed 2750 rows.
# Processed 2760 rows.
# Processed 2770 rows.
# Processed 2780 rows.
# Processed 2790 rows.
# Processed 2800 rows.
# Processed 2810 rows.
# Processed 2820 rows.
# Processed 2830 rows.
# Processed 2840 rows.
# Processed 2850 rows.
# Processed 2860 rows.
# Processed 2870 rows.
# Processed 2880 rows.
# Processed 2890 rows.
# Processed 2900 rows.
# Processed 2910 rows.
# Processed 2920 rows.
# Processed 2930 rows.
# Processed 2940 rows.
# Processed 2950 rows.
# Processed 2960 rows.
# Processed 2970 rows.
# Processed 2980 rows.
# Processed 2990 rows.
# Processed 3000 rows.
# Processed 3010 rows.
# Processed 3020 rows.
# Processed 3030 rows.
# Processed 3040 rows.
# Processed 3050 rows.
# Processed 3060 rows.
# Processed 3070 rows.
# Processed 3080 rows.
# Processed 3090 rows.
# Processed 3100 rows.
# Processed 3110 rows.
# Processed 3120 rows.
# Processed 3130 rows.
# Processed 3140 rows.
# Processed 3150 rows.
# Processed 3160 rows.
# Processed 3170 rows.
# Processed 3180 rows.
# Processed 3190 rows.
# Processed 3200 rows.
# Processed 3210 rows.
# Processed 3220 rows.
# Processed 3230 rows.
# Processed 3240 rows.
# Processed 3250 rows.
# Processed 3260 rows.
# Processed 3270 rows.
# Processed 3280 rows.
# Processed 3290 rows.
# Processed 3300 rows.
# Processed 3310 rows.
# Processed 3320 rows.
# Processed 3330 rows.
# Processed 3340 rows.
# Processed 3350 rows.
# Processed 3360 rows.
# Processed 3370 rows.
# Processed 3380 rows.
# Processed 3390 rows.
# Processed 3400 rows.
# Processed 3410 rows.
# Processed 3420 rows.
# Processed 3430 rows.
# Processed 3440 rows.
# Processed 3450 rows.
# Processed 3460 rows.
# Processed 3470 rows.
# Processed 3480 rows.
# Processed 3490 rows.
# Processed 3500 rows.
# Processed 3510 rows.
# Processed 3520 rows.
# Processed 3530 rows.
# Processed 3540 rows.
# Processed 3550 rows.
# Processed 3560 rows.
# Processed 3570 rows.
# Processed 3580 rows.
# Processed 3590 rows.
# Processed 3600 rows.
# Processed 3610 rows.
# Processed 3620 rows.
# Processed 3630 rows.
# Processed 3640 rows.
# Processed 3650 rows.
# Processed 3660 rows.
# Processed 3670 rows.
# Processed 3680 rows.
# Processed 3690 rows.
# Processed 3700 rows.
# Processed 3710 rows.
# Processed 3720 rows.
# Processed 3730 rows.
# Processed 3740 rows.
# Processed 3750 rows.
# Processed 3760 rows.
# Processed 3770 rows.
# Processed 3780 rows.
# Processed 3790 rows.
# Processed 3800 rows.
# Processed 3810 rows.
# Processed 3820 rows.
# Processed 3830 rows.
# Processed 3840 rows.
# Processed 3850 rows.
# Processed 3860 rows.
# Processed 3870 rows.
# Processed 3880 rows.
# Processed 3890 rows.
# Processed 3900 rows.
# Processed 3910 rows.
# Processed 3920 rows.
# Processed 3930 rows.
# Processed 3940 rows.
# Processed 3950 rows.
# Processed 3960 rows.
# Processed 3970 rows.
# Processed 3980 rows.
# Processed 3990 rows.
# Processed 4000 rows.
# Processed 4010 rows.
# Processed 4020 rows.
# Processed 4030 rows.
# Processed 4040 rows.
# Processed 4050 rows.
# Processed 4060 rows.
# Processed 4070 rows.
# Processed 4080 rows.
# Processed 4090 rows.
# Processed 4100 rows.
# Processed 4110 rows.
# Processed 4120 rows.
# Processed 4130 rows.
# Processed 4140 rows.
# Processed 4150 rows.
# Processed 4160 rows.
# Processed 4170 rows.
# Processed 4180 rows.
# Processed 4190 rows.
# Processed 4200 rows.
# Processed 4210 rows.
# Processed 4220 rows.
# Processed 4230 rows.
# Processed 4240 rows.
# Processed 4250 rows.
# Processed 4260 rows.
# Processed 4270 rows.
# Processed 4280 rows.
# Processed 4290 rows.
# Processed 4300 rows.
# Processed 4310 rows.
# Processed 4320 rows.
# Processed 4330 rows.
# Processed 4340 rows.
# Processed 4350 rows.
# Processed 4360 rows.
# Processed 4370 rows.
# Processed 4380 rows.
# Processed 4390 rows.
# Processed 4400 rows.
# Processed 4410 rows.
# Processed 4420 rows.
# Processed 4430 rows.
# Processed 4440 rows.
# Processed 4450 rows.
# Processed 4460 rows.
# Processed 4470 rows.
# Processed 4480 rows.
# Processed 4490 rows.
# Processed 4500 rows.
# Processed 4510 rows.
# Processed 4520 rows.
# Processed 4530 rows.
# Processed 4540 rows.
# Processed 4550 rows.
# Processed 4560 rows.
# Processed 4570 rows.
# Processed 4580 rows.
# Processed 4590 rows.
# Processed 4600 rows.
# Processed 4610 rows.
# Processed 4620 rows.
# Processed 4630 rows.
# Processed 4640 rows.
# Processed 4650 rows.
# Processed 4660 rows.
# Processed 4670 rows.
# Processed 4680 rows.
# Processed 4690 rows.
# Processed 4700 rows.
# Processed 4710 rows.
# Processed 4720 rows.
# Processed 4730 rows.
# Processed 4740 rows.
# Processed 4750 rows.
# Processed 4760 rows.
# Processed 4770 rows.
# Processed 4780 rows.
# Processed 4790 rows.
# Processed 4800 rows.
# Processed 4810 rows.
# Processed 4820 rows.
# Processed 4830 rows.
# Processed 4840 rows.
# Processed 4850 rows.
# Processed 4860 rows.
# Processed 4870 rows.
# Processed 4880 rows.
# Processed 4890 rows.
# Processed 4900 rows.
# Processed 4910 rows.
# Processed 4920 rows.
# Processed 4930 rows.
# Processed 4940 rows.
# Processed 4950 rows.
# Processed 4960 rows.
# Processed 4970 rows.
# Processed 4980 rows.
# Processed 4990 rows.
# Processed 5000 rows.
# Processed 5010 rows.
# Processed 5020 rows.
# Processed 5030 rows.
# Processed 5040 rows.
# Processed 5050 rows.
# Processed 5060 rows.
# Processed 5070 rows.
# Processed 5080 rows.
# Processed 5090 rows.
# Processed 5100 rows.
# Processed 5110 rows.
# Processed 5120 rows.
# Processed 5130 rows.
# Processed 5140 rows.
# Processed 5150 rows.
# Processed 5160 rows.
# Processed 5170 rows.
# Processed 5180 rows.
# Processed 5190 rows.
# Processed 5200 rows.
# Processed 5210 rows.
# Processed 5220 rows.
# Processed 5230 rows.
# Processed 5240 rows.
# Processed 5250 rows.
# Processed 5260 rows.
# Processed 5270 rows.
# Processed 5280 rows.
# Processed 5290 rows.
# Processed 5300 rows.
# Processed 5310 rows.
# Processed 5320 rows.
# Processed 5330 rows.
# Processed 5340 rows.
# Processed 5350 rows.
# Processed 5360 rows.
# Processed 5370 rows.
# Processed 5380 rows.
# Processed 5390 rows.
# Processed 5400 rows.
# Processed 5410 rows.
# Processed 5420 rows.
# Processed 5430 rows.
# Processed 5440 rows.
# Processed 5450 rows.
# Processed 5460 rows.
# Processed 5470 rows.
# Processed 5480 rows.
# Processed 5490 rows.
# Processed 5500 rows.
# Processed 5510 rows.
# Processed 5520 rows.
# Processed 5530 rows.
# Processed 5540 rows.
# Processed 5550 rows.
# Processed 5560 rows.
# Processed 5570 rows.
# Processed 5580 rows.
# Processed 5590 rows.
# Processed 5600 rows.
# Processed 5610 rows.
# Processed 5620 rows.
# Processed 5630 rows.
# Processed 5640 rows.
# Processed 5650 rows.
# Processed 5660 rows.
# Processed 5670 rows.
# Processed 5680 rows.
# Processed 5690 rows.
# Processed 5700 rows.
# Processed 5710 rows.
# Processed 5720 rows.
# Processed 5730 rows.
# Processed 5740 rows.
# Processed 5750 rows.
# Processed 5760 rows.
# Processed 5770 rows.
# Processed 5780 rows.
# Processed 5790 rows.
# Processed 5800 rows.
# Processed 5810 rows.
# Processed 5820 rows.
# Processed 5830 rows.
# Processed 5840 rows.
# Processed 5850 rows.
# Processed 5860 rows.
# Processed 5870 rows.
# Processed 5880 rows.
# Processed 5890 rows.
# Processed 5900 rows.
# Processed 5910 rows.
# Processed 5920 rows.
# Processed 5930 rows.
# Processed 5940 rows.
# Processed 5950 rows.
# Processed 5960 rows.
# Processed 5970 rows.
# Processed 5980 rows.
# Processed 5990 rows.
# Processed 6000 rows.
# Processed 6010 rows.
# Processed 6020 rows.
# Processed 6030 rows.
# Processed 6040 rows.
# Processed 6050 rows.
# Processed 6060 rows.
# Processed 6070 rows.
# Processed 6080 rows.
# Processed 6090 rows.
# Processed 6100 rows.
# Processed 6110 rows.
# Processed 6120 rows.
# Processed 6130 rows.
# Processed 6140 rows.
# Processed 6150 rows.
# Processed 6160 rows.
# Processed 6170 rows.
# Processed 6180 rows.
# Processed 6190 rows.
# Processed 6200 rows.
# Processed 6210 rows.
# Processed 6220 rows.
# Processed 6230 rows.
# Processed 6240 rows.
# Processed 6250 rows.
# Processed 6260 rows.
# Processed 6270 rows.
# Processed 6280 rows.
# Processed 6290 rows.
# Processed 6300 rows.
# Processed 6310 rows.
# Processed 6320 rows.
# Processed 6330 rows.
# Processed 6340 rows.
# Processed 6350 rows.
# Processed 6360 rows.
# Processed 6370 rows.
# Processed 6380 rows.
# Processed 6390 rows.
# Processed 6400 rows.
# Processed 6410 rows.
# Processed 6420 rows.
# Processed 6430 rows.
# Processed 6440 rows.
# Processed 6450 rows.
# Processed 6460 rows.
# Processed 6470 rows.
# Processed 6480 rows.
# Processed 6490 rows.
# Processed 6500 rows.
# Processed 6510 rows.
# Processed 6520 rows.
# Processed 6530 rows.
# Processed 6540 rows.
# Processed 6550 rows.
# Processed 6560 rows.
# Processed 6570 rows.
# Processed 6580 rows.
# Processed 6590 rows.
# Processed 6600 rows.
# Processed 6610 rows.
# Processed 6620 rows.
# Processed 6630 rows.
# Processed 6640 rows.
# Processed 6650 rows.
# Processed 6660 rows.
# Processed 6670 rows.
# Processed 6680 rows.
# Processed 6690 rows.
# Processed 6700 rows.
# Processed 6710 rows.
# Processed 6720 rows.
# Processed 6730 rows.
# Processed 6740 rows.
# Processed 6750 rows.
# Processed 6760 rows.
# Processed 6770 rows.
# Processed 6780 rows.
# Processed 6790 rows.
# Processed 6800 rows.
# Processed 6810 rows.
# Processed 6820 rows.
# Processed 6830 rows.
# Processed 6840 rows.
# Processed 6850 rows.
# Processed 6860 rows.
# Processed 6870 rows.
# Processed 6880 rows.
# Processed 6890 rows.
# Processed 6900 rows.
# Processed 6910 rows.
# Processed 6920 rows.
# Processed 6930 rows.
# Processed 6940 rows.
# Processed 6950 rows.
# Processed 6960 rows.
# Processed 6970 rows.
# Processed 6980 rows.
# Processed 6990 rows.
# Processed 7000 rows.
# Processed 7010 rows.
# Processed 7020 rows.
# Processed 7030 rows.
# Processed 7040 rows.
# Processed 7050 rows.
# Processed 7060 rows.
# Processed 7070 rows.
# Processed 7080 rows.
# Processed 7090 rows.
# Processed 7100 rows.
# Processed 7110 rows.
# Processed 7120 rows.
# Processed 7130 rows.
# Processed 7140 rows.
# Processed 7150 rows.
# Processed 7160 rows.
# Processed 7170 rows.
# Processed 7180 rows.
# Processed 7190 rows.
# Processed 7200 rows.
# Processed 7210 rows.
# Processed 7220 rows.
# Processed 7230 rows.
# Processed 7240 rows.
# Processed 7250 rows.
# Processed 7260 rows.
# Processed 7270 rows.
# Processed 7280 rows.
# Processed 7290 rows.
# Processed 7300 rows.
# Processed 7310 rows.
# Processed 7320 rows.
# Processed 7330 rows.
# Processed 7340 rows.
# Processed 7350 rows.
# Processed 7360 rows.
# Processed 7370 rows.
# Processed 7380 rows.
# Processed 7390 rows.
# Processed 7400 rows.
# Processed 7410 rows.
# Processed 7420 rows.
# Processed 7430 rows.
# Processed 7440 rows.
# Processed 7450 rows.
# Processed 7460 rows.
# Processed 7470 rows.
# Processed 7480 rows.
# Processed 7490 rows.
# Processed 7500 rows.
# Processed 7510 rows.
# Processed 7520 rows.
# Processed 7530 rows.
# Processed 7540 rows.
# Processed 7550 rows.
# Processed 7560 rows.
# Processed 7570 rows.
# Processed 7580 rows.
# Processed 7590 rows.
# Processed 7600 rows.
# Processed 7610 rows.
# Processed 7620 rows.
# Processed 7630 rows.
# Processed 7640 rows.
# Processed 7650 rows.
# Processed 7660 rows.
# Processed 7670 rows.
# Processed 7680 rows.
# Processed 7690 rows.
# Processed 7700 rows.
# Processed 7710 rows.
# Processed 7720 rows.
# Processed 7730 rows.
# Processed 7740 rows.
# Processed 7750 rows.
# Processed 7760 rows.
# Processed 7770 rows.
# Processed 7780 rows.
# Processed 7790 rows.
# Processed 7800 rows.
# Processed 7810 rows.
# Processed 7820 rows.
# Processed 7830 rows.
# Processed 7840 rows.
# Processed 7850 rows.
# Processed 7860 rows.
# Processed 7870 rows.
# Processed 7880 rows.
# Processed 7890 rows.
# Processed 7900 rows.
# Processed 7910 rows.
# Processed 7920 rows.
# Processed 7930 rows.
# Processed 7940 rows.
# Processed 7950 rows.
# Processed 7960 rows.
# Processed 7970 rows.
# Processed 7980 rows.
# Processed 7990 rows.
# Processed 8000 rows.
# Processed 8010 rows.
# Processed 8020 rows.
# Processed 8030 rows.
# Processed 8040 rows.
# Processed 8050 rows.
# Processed 8060 rows.
# Processed 8070 rows.
# Processed 8080 rows.
# Processed 8090 rows.
# Processed 8100 rows.
# Processed 8110 rows.
# Processed 8120 rows.
# Processed 8130 rows.
# Processed 8140 rows.
# Processed 8150 rows.
# Processed 8160 rows.
# Processed 8170 rows.
# Processed 8180 rows.
# Processed 8190 rows.
# Processed 8200 rows.
# Processed 8210 rows.
# Processed 8220 rows.
# Processed 8230 rows.
# Processed 8240 rows.
# Processed 8250 rows.
# Processed 8260 rows.
# Processed 8270 rows.
# Processed 8280 rows.
# Processed 8290 rows.
# Processed 8300 rows.
# Processed 8310 rows.
# Processed 8320 rows.
# Processed 8330 rows.
# Processed 8340 rows.
# Processed 8350 rows.
# Processed 8360 rows.
# Processed 8370 rows.
# Processed 8380 rows.
# Processed 8390 rows.
# Processed 8400 rows.
# Processed 8410 rows.
# Processed 8420 rows.
# Processed 8430 rows.
# Processed 8440 rows.
# Processed 8450 rows.
# Processed 8460 rows.
# Processed 8470 rows.
# Processed 8480 rows.
# Processed 8490 rows.
# Processed 8500 rows.
# Processed 8510 rows.
# Processed 8520 rows.
# Processed 8530 rows.
# Processed 8540 rows.
# Processed 8550 rows.
# Processed 8560 rows.
# Processed 8570 rows.
# Processed 8580 rows.
# Processed 8590 rows.
# Processed 8600 rows.
# Processed 8610 rows.
# Processed 8620 rows.
# Processed 8630 rows.
# Processed 8640 rows.
# Processed 8650 rows.
# Processed 8660 rows.
# Processed 8670 rows.
# Processed 8680 rows.
# Processed 8690 rows.
# Processed 8700 rows.
# Processed 8710 rows.
# Processed 8720 rows.
# Processed 8730 rows.
# Processed 8740 rows.
# Processed 8750 rows.
# Processed 8760 rows.
# Processed 8770 rows.
# Processed 8780 rows.
# Processed 8790 rows.
# Processed 8800 rows.
# Processed 8810 rows.
# Processed 8820 rows.
# Processed 8830 rows.
# Processed 8840 rows.
# Processed 8850 rows.
# Processed 8860 rows.
# Processed 8870 rows.
# Processed 8880 rows.
# Processed 8890 rows.
# Processed 8900 rows.
# Processed 8910 rows.
# Processed 8920 rows.
# Processed 8930 rows.
# Processed 8940 rows.
# Processed 8950 rows.
# Processed 8960 rows.
# Processed 8970 rows.
# Processed 8980 rows.
# Processed 8990 rows.
# Processed 9000 rows.
# Processed 9010 rows.
# Processed 9020 rows.
# Processed 9030 rows.
# Processed 9040 rows.
# Processed 9050 rows.
# Processed 9060 rows.
# Processed 9070 rows.
# Processed 9080 rows.
# Processed 9090 rows.
# Processed 9100 rows.
# Processed 9110 rows.
# Processed 9120 rows.
# Processed 9130 rows.
# Processed 9140 rows.
# Processed 9150 rows.
# Processed 9160 rows.
# Processed 9170 rows.
# Processed 9180 rows.
# Processed 9190 rows.
# Processed 9200 rows.
# Processed 9210 rows.
# Processed 9220 rows.
# Processed 9230 rows.
# Processed 9240 rows.
# Processed 9250 rows.
# Processed 9260 rows.
# Processed 9270 rows.
# Processed 9280 rows.
# Processed 9290 rows.
# Processed 9300 rows.
# Processed 9310 rows.
# Processed 9320 rows.
# Processed 9330 rows.
# Processed 9340 rows.
# Processed 9350 rows.
# Processed 9360 rows.
# Processed 9370 rows.
# Processed 9380 rows.
# Processed 9390 rows.
# Processed 9400 rows.
# Processed 9410 rows.
# Processed 9420 rows.
# Processed 9430 rows.
# Processed 9440 rows.
# Processed 9450 rows.
# Processed 9460 rows.
# Processed 9470 rows.
# Processed 9480 rows.
# Processed 9490 rows.
# Processed 9500 rows.
# Processed 9510 rows.
# Processed 9520 rows.
# Processed 9530 rows.
# Processed 9540 rows.
# Processed 9550 rows.
# Processed 9560 rows.
# Processed 9570 rows.
# Processed 9580 rows.
# Processed 9590 rows.
# Processed 9600 rows.
# Processed 9610 rows.
# Processed 9620 rows.
# Processed 9630 rows.
# Processed 9640 rows.
# Processed 9650 rows.
# Processed 9660 rows.
# Processed 9670 rows.
# Processed 9680 rows.
# Processed 9690 rows.
# Processed 9700 rows.
# Processed 9710 rows.
# Processed 9720 rows.
# Processed 9730 rows.
# Processed 9740 rows.
# Processed 9750 rows.
# Processed 9760 rows.
# Processed 9770 rows.
# Processed 9780 rows.
# Processed 9790 rows.
# Processed 9800 rows.
# Processed 9810 rows.
# Processed 9820 rows.
# Processed 9830 rows.
# Processed 9840 rows.
# Processed 9850 rows.
# Processed 9860 rows.
# Processed 9870 rows.
# Processed 9880 rows.
# Processed 9890 rows.
# Processed 9900 rows.
# Processed 9910 rows.
# Processed 9920 rows.
# Processed 9930 rows.
# Processed 9940 rows.
# Processed 9950 rows.
# Processed 9960 rows.
# Processed 9970 rows.
# Processed 9980 rows.
# Processed 9990 rows.
# Processed 10000 rows.
# Processed 10010 rows.
# Processed 10020 rows.
# Processed 10030 rows.
# Processed 10040 rows.
# Processed 10050 rows.
# Processed 10060 rows.
# Processed 10070 rows.
# Processed 10080 rows.
# Processed 10090 rows.
# Processed 10100 rows.
# Processed 10110 rows.
# Processed 10120 rows.
# Processed 10130 rows.
# Processed 10140 rows.
# Processed 10150 rows.
# Processed 10160 rows.
# Processed 10170 rows.
# Processed 10180 rows.
# Processed 10190 rows.
# Processed 10200 rows.
# Processed 10210 rows.
# Processed 10220 rows.
# Processed 10230 rows.
# Processed 10240 rows.
# Processed 10250 rows.
# Processed 10260 rows.
# Processed 10270 rows.
# Processed 10280 rows.
# Processed 10290 rows.
# Processed 10300 rows.
# Processed 10310 rows.
# Processed 10320 rows.
# Processed 10330 rows.
# Processed 10340 rows.
# Processed 10350 rows.
# Processed 10360 rows.
# Processed 10370 rows.
# Processed 10380 rows.
# Processed 10390 rows.
# Processed 10400 rows.
# Processed 10410 rows.
# Processed 10420 rows.
# Processed 10430 rows.
# Processed 10440 rows.
# Processed 10450 rows.
# Processed 10460 rows.
# Processed 10470 rows.
# Processed 10480 rows.
# Processed 10490 rows.
# Processed 10500 rows.
# Processed 10510 rows.
# Processed 10520 rows.
# Processed 10530 rows.
# Processed 10540 rows.
# Processed 10550 rows.
# Processed 10560 rows.
# Processed 10570 rows.
# Processed 10580 rows.
# Processed 10590 rows.
# Processed 10600 rows.
# Processed 10610 rows.
# Processed 10620 rows.
# Processed 10630 rows.
# Processed 10640 rows.
# Processed 10650 rows.
# Processed 10660 rows.
# Processed 10670 rows.
# Processed 10680 rows.
# Processed 10690 rows.
# Processed 10700 rows.
# Processed 10710 rows.
# Processed 10720 rows.
# Processed 10730 rows.
# Processed 10740 rows.
# Processed 10750 rows.
# Processed 10760 rows.
# Processed 10770 rows.
# Processed 10780 rows.
# Processed 10790 rows.
# Processed 10800 rows.
# Processed 10810 rows.
# Processed 10820 rows.
# Processed 10830 rows.
# Processed 10840 rows.
# Processed 10850 rows.
# Processed 10860 rows.
# Processed 10870 rows.
# Results written to raw_data/ScienceQA_processed.json
# Results with images written to raw_data/ScienceQA_processed_with_image.json
